# %% [markdown]
# # Exercise 1 (sorted)

# %% [markdown]
# Overview:
# - A student's grades on different subjects are given. The student would like help prioritizing which subject's homework to work on. Ideally, their worst subject should be worked on first, followed by their second subject, … . Their best subject should be worked on last
# - Goal: Reorder the list to match this ordering
# - Use this sorted() function
#
# Resources:
# - sorted() syntax ([link](https://docs.python.org/3/library/functions.html#sorted))
# - sorted() syntax and examples ([link](https://www.w3schools.com/python/ref_func_sorted.asp))
# - Tuple indexing ([link](https://www.tutorialspoint.com/python/python_tuples.htm))

# %%
grades = [ ("English", 88), ("Science", 90), ("Maths", 97), ("Social Sciences", 82) ]

# %% [markdown]
# Solution 1: Pass function as argument

# %%
# Input: element in the list
# Output: the attribute we'd like to sort on
def get_sorting_attribute(x):
  # TODO: Implement
  return x

# %%
sorted_grades = sorted(grades, key=get_sorting_attribute)

# %%
for grade in sorted_grades:
  print(grade)
# Out:
# ('English', 88)
# ('Maths', 97)
# ('Science', 90)
# ('Social Sciences', 82)

# %% [markdown]
# Solution 2: Use lambda function

# %%
# Solution 2: use lambda function

# TODO: Implement
sorted_grades = sorted(grades, key=lambda x: x)

# %%
for grade in sorted_grades:
  print(grade)
# Out:
# ('English', 88)
# ('Maths', 97)
# ('Science', 90)
# ('Social Sciences', 82)

# %% [markdown]
# # Exercise 2 (map)

# %% [markdown]
# Overview:
# - U of M departments within LSA are given. We'd like to get their acronyms (e.g. "School of Information" → "SI"). Note that we'd like to avoid "filler" words that appear as lower case (e.g. "of", "the")
# - Goal: Convert this list to a list of acronyms
# - Use the map() function
#
# Resources:
# - map() Syntax and examples ([link](https://www.geeksforgeeks.org/python-map-function/))
# - More LSA departments ([link](https://lsa.umich.edu/lsa/academics/departments-and-units.html))
#
# - Split string on character ([link](https://www.w3schools.com/python/ref_string_split.asp))
# - Check chracater is upper case ([link](https://www.geeksforgeeks.org/isupper-islower-lower-upper-python-applications/))
# - Concatenate characters/strings ([link](https://www.w3schools.com/python/gloss_python_string_concatenation.asp))

# %%
depts = [ "School of Information", "Museum of Anthropological Archaeology", "Center for the Study of Complex Systems" ]

# %% [markdown]
# Solution 1: Pass function as argument

# %%
# input: an element in the list
# output: the transformed element
def get_acronym(x):
  # TODO: Implement
  return x

# %%
shortened_depts = map(get_acronym, depts)

# %%
for sd in shortened_depts:
  print(sd)
# Out:
# School of Information
# Museum of Anthropological Archaeology
# Center for the Study of Complex Systems

# %% [markdown]
# Solution 2: Use lambda function(s) (challenge)

# %%
# TODO: Implement
shortened_depts = map(lambda x: x, depts)

# %%
for sd in shortened_depts:
  print(sd)
# Out:
# School of Information
# Museum of Anthropological Archaeology
# Center for the Study of Complex Systems

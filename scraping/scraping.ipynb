# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# %% [markdown]
# We will be using chessresults.com, which is a website that stores and displays data regarding chess tournament outcomes

# %%
# Get the website html

url = 'https://chess-results.com/tnr669871.aspx?lan=1'

req = Request(url)
html_page = urlopen(req)
soup = BeautifulSoup(html_page, 'html.parser')

# %% [markdown]
# Q1: What is the name of the tournament?
#
#
# *   Find an element attribute that uniquely identifies the name
# *   Select that element

# %%
obj_list = soup.select('TODO')
obj = obj_list[0]
text = obj.text
print(text)

# %% [markdown]
# Q2: What is the name of the ninth row's player?
#
# *   Find the element attributes that represent the rows in the table
# *   Select on those attributes to get a list of the rows
# *   Within the desired row, select the values
# *   Get the desired value

# %%
row_idx = 9
name_idx = 3

# Get a list of all the row objects
rows = soup.select('TODO')

# Select the desired row
row  = rows[row_idx]
print(row)

# Within the desired row, select the values
row_vals = row.select('TODO')

# Get the desired value
name = [name_idx].text

print(name)
